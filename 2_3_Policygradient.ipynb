# %% [markdown]
# <a href="https://colab.research.google.com/github/jeonniga/pytorch-dqn/blob/main/2_3_Policygradient.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 구현에 사용할 패키지 임포트하기
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 초기 상태의 미로 모습

# 전체 그림의 크기 및 그림을 나타내는 변수 선언
fig = plt.figure(figsize=(5, 5))
ax = plt.gca()

# 붉은 벽 그리기
plt.plot([1, 1], [0, 1], color='red', linewidth=2)
plt.plot([1, 2], [2, 2], color='red', linewidth=2)
plt.plot([2, 2], [2, 1], color='red', linewidth=2)
plt.plot([2, 3], [1, 1], color='red', linewidth=2)

# 상태를 의미하는 문자열(S0~S8) 표시
plt.text(0.5, 2.5, 'S0', size=14, ha='center')
plt.text(1.5, 2.5, 'S1', size=14, ha='center')
plt.text(2.5, 2.5, 'S2', size=14, ha='center')
plt.text(0.5, 1.5, 'S3', size=14, ha='center')
plt.text(1.5, 1.5, 'S4', size=14, ha='center')
plt.text(2.5, 1.5, 'S5', size=14, ha='center')
plt.text(0.5, 0.5, 'S6', size=14, ha='center')
plt.text(1.5, 0.5, 'S7', size=14, ha='center')
plt.text(2.5, 0.5, 'S8', size=14, ha='center')
plt.text(0.5, 2.3, 'START', ha='center')
plt.text(2.5, 0.3, 'GOAL', ha='center')

# 그림을 그릴 범위 및 눈금 제거 설정
ax.set_xlim(0, 3)
ax.set_ylim(0, 3)
plt.tick_params(axis='both', which='both', bottom=False, top=False,
                labelbottom=False, right=False, left=False, labelleft=False)

# S0에 녹색 원으로 현재 위치를 표시
line, = ax.plot([0.5], [2.5], marker="o", color='g', markersize=60)

# %%
# 정책을 결정하는 파라미터의 초깃값 theta_0를 설정

# 줄은 상태 0~7, 열은 행동방향(상,우,하,좌 순)를 나타낸다
theta_0 = np.array([[np.nan, 1, 1, np.nan],       # s0
                    [np.nan, 1, np.nan, 1],       # s1
                    [np.nan, np.nan, 1, 1],       # s2
                    [1, 1, 1, np.nan],            # s3
                    [np.nan, np.nan, 1, 1],       # s4
                    [1, np.nan, np.nan, np.nan],  # s5
                    [1, np.nan, np.nan, np.nan],  # s6
                    [1, 1, np.nan, np.nan],       # s7、※s8은 목표지점이므로 정책이 없다
                    ])

# %%
# 정책 파라미터 theta를 행동정책 pi로 변환(소프트맥스 함수 사용)하는 함수
def softmax_convert_into_pi_from_theta(theta):
    '''비율 계산에 소프트맥스 함수 사용'''

    beta = 1.0
    [m, n] = theta.shape  # theta의 행렬 크기를 구함
    pi = np.zeros((m, n))

    exp_theta = np.exp(beta * theta)  # theta를 exp(theta)로 변환

    for i in range(0, m):
        # pi[i, :] = theta[i, :] / np.nansum(theta[i, :])
        # 단순 비율을 계산하는 코드

        pi[i, :] = exp_theta[i, :] / np.nansum(exp_theta[i, :])
        # softmax로 계산하는 코드

    pi = np.nan_to_num(pi)  # nan을 0으로 변환

    return pi

# %%
# 초기 정책 pi_0을 계산
pi_0 = softmax_convert_into_pi_from_theta(theta_0)
print(pi_0)
# Out:
# [[0.         0.5        0.5        0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33333333 0.33333333 0.33333333 0.        ]
#  [0.         0.         0.5        0.5       ]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.5        0.5        0.         0.        ]]

# %%
# 행동 a를 취한 후의 상태 s를 구하는 함수

def get_action_and_next_s(pi, s):
    direction = ["up", "right", "down", "left"]
    # pi[s,:]의 확률을 따라, direction값이 선택된다
    next_direction = np.random.choice(direction, p=pi[s, :])

    if next_direction == "up":
        action = 0
        s_next = s - 3  # 위로 이동하면 상태값이 3 줄어든다
    elif next_direction == "right":
        action = 1
        s_next = s + 1  # 오른쪽으로 이동하면 상태값이 1 늘어난다
    elif next_direction == "down":
        action = 2
        s_next = s + 3  # 아래로 이동하면 상태값이 3 늘어난다
    elif next_direction == "left":
        action = 3
        s_next = s - 1  # 왼쪽으로 이동하면 상태값이 1 줄어든다

    return [action, s_next]

# %%
# 미로를 빠져나오는 함수, 상태와 행동의 히스토리를 출력한다


def goal_maze_ret_s_a(pi):
    s = 0  # 시작 지점
    s_a_history = [[0, np.nan]]  # 에이전트의 행동 및 상태의 히스토리를 기록하는 리스트

    while (1):  # 목표 지점에 이를 때까지 반복
        [action, next_s] = get_action_and_next_s(pi, s)
        s_a_history[-1][1] = action
        # 현재 상태(마지막이므로 인덱스가 -1)를 히스토리에 추가

        s_a_history.append([next_s, np.nan])
        # 다음 상태를 히스토리에 추가, 행동은 아직 알 수 없으므로 nan으로 둔다.

        if next_s == 8:  # 목표 지점에 이르면 종료
            break
        else:
            s = next_s

    return s_a_history

# %%
# 초기 정책으로 미로를 빠져나오기
s_a_history = goal_maze_ret_s_a(pi_0)
print(s_a_history)
print("목표 지점에 이르기까지 걸린 단계 수는 " + str(len(s_a_history) - 1) + "단계입니다")
# Out:
# [[0, 2], [3, 1], [4, 2], [7, 0], [4, 2], [7, 1], [8, nan]]
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다

# %%
# theta를 수정하는 함수

def update_theta(theta, pi, s_a_history):
    eta = 0.1 # 학습률
    T = len(s_a_history) - 1                # 목표 지점에 이르기까지 걸린 단계 수

    [m, n] = theta.shape                    # theta의 행렬 크기를 구함
    delta_theta = theta.copy()              # Δtheta를 구할 준비, 포인터 참조이므로 delta_theta = theta로는 안됨

    # delta_theta를 요소 단위로 계산
    for i in range(0, m):
        for j in range(0, n):
            if not(np.isnan(theta[i, j])):  # theta가 nan이 아닌 경우

                SA_i = [SA for SA in s_a_history if SA[0] == i]
                # 히스토리에서 상태 i인 것만 모아오는 리스트 컴프리헨션

                SA_ij = [SA for SA in s_a_history if SA == [i, j]]
                # 상태 i에서 행동 j를 취한 경우만 모음

                N_i = len(SA_i)             # 상태 i에서 모든 행동을 취한 횟수
                N_ij = len(SA_ij)           # 상태 i에서 행동 j를 취한 횟수 
                
                # 초판에서 부호 오류가 있었음(수정일 : 1807030
                #delta_theta[i, j] = (N_ij + pi[i, j] * N_i) / T
                delta_theta[i, j] = (N_ij - pi[i, j] * N_i) / T

    new_theta = theta + eta * delta_theta

    return new_theta

# %%
# 정책 수정
new_theta = update_theta(theta_0, pi_0, s_a_history)
pi = softmax_convert_into_pi_from_theta(new_theta)
print(pi)
# Out:
# [[0.         0.49583343 0.50416657 0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33147637 0.33704727 0.33147637 0.        ]
#  [0.         0.         0.50833256 0.49166744]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.5        0.5        0.         0.        ]]

# %%
# 정책 경사 알고리즘으로 미로 빠져나오기

stop_epsilon = 10**-4                                       # 정책의 변화가 10^-4 보다 작아지면 학습을 종료


theta = theta_0
pi = pi_0

is_continue = True
count = 1
while is_continue:                                          # is_continue가 False가 될 때까지 반복
    s_a_history = goal_maze_ret_s_a(pi)                     # 정책 π를 따라 미로를 탐색한 히스토리를 구함
    new_theta = update_theta(theta, pi, s_a_history)        # 파라미터 Θ를 수정
    new_pi = softmax_convert_into_pi_from_theta(new_theta)  # 정책 π를 수정

    print(np.sum(np.abs(new_pi - pi)))                      # 정책의 변화를 출력
    print("목표 지점에 이르기까지 걸린 단계 수는 " + str(len(s_a_history) - 1) + "단계입니다")

    if np.sum(np.abs(new_pi - pi)) < stop_epsilon:
        is_continue = False
    else:
        theta = new_theta
        pi = new_pi
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 0.002736010795933469
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.0027822779243609035
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.0033075059771292374
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.0006915768473098778
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006887440737065875
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006859289833858993
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006831314276616526
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.000680351259419669
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006775883330964669
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006748425046589207
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006721136315859279
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006694015728501458
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006667061888960928
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0033035786373812603
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.0006773705622515475
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006746111593964252
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006718689368611017
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.000669143750216903
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006664354565640816
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006637439145106144
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006610689841562364
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006584105270696604
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006557684062719338
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006531424862200076
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006505326327841884
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006479387132346769
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.010831622268157915
# 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.0006480583270734586
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006454869062617538
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006429310587849901
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006403906573485448
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006378655759670115
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.002701609440177076
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.0006434310107255939
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006408898799814822
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006383640435040326
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006358533772674868
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.003224194471487675
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.0006461267858669101
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006435555161943378
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.006930317528212587
# 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.0006514663993496782
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006488721633879438
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006462936850991988
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006437308354401462
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.011158962733084404
# 목표 지점에 이르기까지 걸린 단계 수는 16단계입니다
# 0.0006425980858598655
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006400611813094925
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006375395444857823
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006350330515358833
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.013429285987391838
# 목표 지점에 이르기까지 걸린 단계 수는 18단계입니다
# 0.0006338281791136088
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006313470123235423
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006288806435604741
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006264289538880294
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.00710962184471799
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.0006280391817131796
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0021652977324221646
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.0006277191910783117
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006252922679864034
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006228796072421244
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006204810959991071
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006180966225332908
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0026652614716848218
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.000623566741940848
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006211656291716106
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006187785520007927
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006164054001340062
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0026913423808792372
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.0006221566917447678
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006197644694056377
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006173861957598711
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006150217616164091
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006126710588591593
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.003104900828834807
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.0006219737421135178
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006195712141001328
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006171827973357399
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006148083802979994
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006124478525696697
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0021582429457479187
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.002203003978244099
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.0006147644694616296
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006124214923278956
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006100920663996041
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006077760862695306
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006054734475600468
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0026625465757529575
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.0006111153548647268
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.000608794151935127
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006064863142230779
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006041917383770926
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006019103220484823
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0005996419638798177
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0026390105772938696
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.0030755357515108404
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.0006170883209850216
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006147221232810467
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.000612369702537377
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006100309509310398
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006077057616972227
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006053940291177971
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006030956485094975
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0006008105162104704
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0005985385295703555
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0005962795869353492
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.000594033587641235
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0005918004319958869
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0005895800212735343
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0005873722576986429
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0005851770444407906
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0005829942855964179
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0030406407841475983
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.0005920415457583185
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0005898088227437662
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0005875889182973097
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0005853817332586719
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0005831871694326508
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.00010075246382116633
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.00010059180980491987
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.00010043154897338737
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.00010027168002174625
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.00010011220164854104
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 9.995311256069152e-05
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다

# %%
# 학습이 끝난 정책을 확인
np.set_printoptions(precision=3, suppress=True)  # 有効桁数3、指数表示しないという設定
print(pi)
# Out:
# [[0.    0.01  0.99  0.   ]
#  [0.    0.314 0.    0.686]
#  [0.    0.    0.42  0.58 ]
#  [0.012 0.974 0.014 0.   ]
#  [0.    0.    0.985 0.015]
#  [1.    0.    0.    0.   ]
#  [1.    0.    0.    0.   ]
#  [0.014 0.986 0.    0.   ]]

# %%
# 에이전트의 이동 과정을 시각화
# 참고 URL http://louistiao.me/posts/notebooks/embedding-matplotlib-animations-in-jupyter-notebooks/
from matplotlib import animation
from IPython.display import HTML


def init():
    # 배경 이미지 초기화
    line.set_data([], [])
    return (line,)


def animate(i):
    # 프레임 단위로 이미지 생성
    state = s_a_history[i][0]   # 현재 위치
    x = (state % 3) + 0.5       # 상태의 x좌표 : 3으로 나눈 나머지 + 0.5
    y = 2.5 - int(state / 3)    # y좌표 : 2.5에서 3으로 나눈 몫을 뺌
    line.set_data(x, y)
    return (line,)


#　초기화 함수와 프레임 단위 이미지 생성한수를 사용하여 애니메이션 생성
anim = animation.FuncAnimation(fig, animate, init_func=init, frames=len(
    s_a_history), interval=200, repeat=False)

HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img22da343c3a9e49e6837dd3e30f4d72d6">
#   <div class="anim-controls">
#     <input id="_anim_slider22da343c3a9e49e6837dd3e30f4d72d6" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim22da343c3a9e49e6837dd3e30f4d72d6.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim22da343c3a9e49e6837dd3e30f4d72d6.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim22da343c3a9e49e6837dd3e30f4d72d6.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim22da343c3a9e49e6837dd3e30f4d72d6.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim22da343c3a9e49e6837dd3e30f4d72d6.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim22da343c3a9e49e6837dd3e30f4d72d6.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim22da343c3a9e49e6837dd3e30f4d72d6.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim22da343c3a9e49e6837dd3e30f4d72d6.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim22da343c3a9e49e6837dd3e30f4d72d6.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim22da343c3a9e49e6837dd3e30f4d72d6.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select22da343c3a9e49e6837dd3e30f4d72d6" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_22da343c3a9e49e6837dd3e30f4d72d6"
#              checked>
#       <label for="_anim_radio1_22da343c3a9e49e6837dd3e30f4d72d6">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_22da343c3a9e49e6837dd3e30f4d72d6"
#              >
#       <label for="_anim_radio2_22da343c3a9e49e6837dd3e30f4d72d6">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_22da343c3a9e49e6837dd3e30f4d72d6"
#              >
#       <label for="_anim_radio3_22da343c3a9e49e6837dd3e30f4d72d6">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img22da343c3a9e49e6837dd3e30f4d72d6";
#     var slider_id = "_anim_slider22da343c3a9e49e6837dd3e30f4d72d6";
#     var loop_select_id = "_anim_loop_select22da343c3a9e49e6837dd3e30f4d72d6";
#     var frames = new Array(5);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjIsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+WH4yJAAAclElEQVR4nO3df1SUdd7/8dfADAgMLH7TDLDAbldZ\
# /OZaoAd0N1PslrbjtmW4B2pLab374VZ30rE669qvb3takzy2+W3z3EprtbX9NHW3VlKj9cfmQrp2\
# a275LVLRFmQ1RX4OfL5/jHgLKwIKXJ+ZeT7OmVMy1wxvPgeeXFxcXOMyxhgBAKwT5vQAAIAzI9AA\
# YCkCDQCWItAAYCkCDQCWItAAYCkCDQCWItAAYCkCDQCWItAAYCkCDQCWItAAYCkCDQCWItAAYCkC\
# DQCWItAAYCkCDQCWItAAYCkCDQCWItAAYCkCDQCWItAAYCkCDQCWItAAYCkCDQCWItAAYCkCDQCW\
# ItAAYCkCDQCWItAAYCkCDQCWItAAYCkCDQCWItAAYCkCDQCWItAAYCkCDQCWItAAYCkCDQCWItAA\
# YCkCDQCWItAAYCm30wOci0GDBik
